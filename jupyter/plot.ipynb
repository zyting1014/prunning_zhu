# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# 中文乱码
import matplotlib as mpl
mpl.rcParams['font.sans-serif'] = ['SimHei']
mpl.rcParams['font.serif'] = ['SimHei']
mpl.rcParams['axes.unicode_minus'] = False # 解决保存图像是负号'-'显示为方块的问题,或者转换负号为字符串

# %%
y = ['1.16', '1.28', '1.24', '1.25', '1.22', '1.19', '1.31', '1.18', '1.14', '1.15', '1.13', '1.09', '1.04', '1.08', '1.04', '1.02', '1.03', '1.13', '0.94', '0.91']

# %%
x =  ['1.00', '0.95', '0.90', '0.85', '0.81', '0.77', '0.73', '0.70', '0.66', '0.63', '0.59', '0.56', '0.53', '0.51', '0.48', '0.46', '0.43', '0.41', '0.39', '0.37']

# %%
y = ['1.13', '1.23', '1.26', '1.24', '1.21', '1.27', '1.38', '1.20', '1.29', '1.24', '1.26', '1.08', '1.24', '1.19', '1.32', '1.20', '1.25', '1.37', '1.24', '1.29', '1.21', '1.25', '1.21', '1.22', '1.27', '1.21', '1.19', '1.23', '1.34', '1.21', '1.22', '1.22', '1.22', '1.30', '1.24', '1.20', '1.22', '1.17', '1.23', '1.38', '1.18', '1.15', '1.27', '1.20', '1.20', '1.22', '1.21', '1.08', '1.28', '1.18', '1.58', '1.19', '1.15', '1.22', '1.19', '1.18', '1.20', '1.22', '1.21', '1.18', '1.13', '1.29', '1.21', '1.14', '1.20', '1.16', '1.15', '1.18', '1.21', '1.13', '1.13', '1.26', '1.37', '1.17', '1.13', '1.12', '1.14', '1.10', '1.16', '1.14', '1.16', '1.07', '1.15', '1.22', '1.12', '1.19', '1.12', '1.13', '1.12', '1.13', '1.14', '1.09', '1.12', '1.11', '1.21', '1.17', '1.11', '1.08', '1.09', '1.11', '1.10', '1.11', '1.10', '1.08', '1.08', '1.24', '1.09', '1.10', '1.10', '1.10', '1.11', '1.10', '1.09', '1.11', '1.09', '1.10', '1.22', '1.09', '1.09', '1.13', '1.12', '1.08', '1.08', '1.10', '1.07', '1.07', '1.11', '1.20', '1.13', '1.04', '1.06', '1.07', '1.15', '1.17', '1.09', '1.06', '1.08', '1.05', '1.17', '1.12', '1.10', '1.08', '1.07', '1.07', '1.08', '1.06', '1.05', '0.99', '1.07', '1.27', '1.07', '1.07', '1.02', '1.07', '1.04', '1.02', '1.17', '1.02', '1.05', '1.04', '1.14', '1.04', '1.01', '1.14', '1.10', '1.04', '1.07', '1.04', '1.06', '1.03', '1.02', '1.53', '1.04', '1.07', '1.13', '1.04', '1.04', '1.03', '1.06', '1.07', '1.05', '1.11', '1.13', '1.02', '1.00', '1.06', '1.01', '1.06', '0.98', '1.05', '1.03', '1.02', '1.01', '1.11', '1.03', '1.00', '1.14', '1.04', '0.99', '1.02', '1.03', '1.02', '1.02', '1.02', '1.12', '1.01', '1.01', '1.02', '1.00', '1.03', '0.98', '0.98', '1.00', '0.95', '0.98', '1.08', '0.98', '1.01', '0.98', '0.97', '0.97', '0.95']
x = [i for i in range (len(y))]

# %%
y = list(map(float, y))
x = list(map(float, x))

# %%
plt.figure(figsize = (10,5))
plt.plot(x,y)
# plt.xlim((max(x),min(x)))
# plt.ylim((min(y) - 0.1,max(y) + 0.1))
plt.xlim((min(x),max(x)))
plt.ylim((min(y),max(y)))
# plt.ylabel("推理时间")
# plt.xlabel("压缩率")
plt.ylabel("推理时间")
plt.xlabel("epoch")
plt.show()
