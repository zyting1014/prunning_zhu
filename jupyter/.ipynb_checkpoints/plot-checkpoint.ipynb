# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# 中文乱码
import matplotlib as mpl
mpl.rcParams['font.sans-serif'] = ['SimHei']
mpl.rcParams['font.serif'] = ['SimHei']
mpl.rcParams['axes.unicode_minus'] = False # 解决保存图像是负号'-'显示为方块的问题,或者转换负号为字符串

# %%
y = ['1.16', '1.28', '1.24', '1.25', '1.22', '1.19', '1.31', '1.18', '1.14', '1.15', '1.13', '1.09', '1.04', '1.08', '1.04', '1.02', '1.03', '1.13', '0.94', '0.91']

# %%
x =  ['1.00', '0.95', '0.90', '0.85', '0.81', '0.77', '0.73', '0.70', '0.66', '0.63', '0.59', '0.56', '0.53', '0.51', '0.48', '0.46', '0.43', '0.41', '0.39', '0.37']

# %%
y = ['1.28', '1.25', '1.28', '1.30', '1.28', '1.34', '1.34', '1.27', '1.30', '1.31', '1.37', '1.23', '1.33', '1.30', '1.32', '1.29', '1.25', '1.41', '1.28', '1.30', '1.31', '1.36', '1.03', '1.11', '1.05', '1.10', '1.04', '1.02', '1.14', '1.02', '1.03', '1.05', '1.01', '1.01', '1.04', '1.02', '1.03', '1.02', '1.10', '1.24', '1.02', '1.05', '1.04', '1.04', '1.09', '1.07', '1.03', '1.02', '1.08', '1.06', '1.16', '1.11', '1.02', '1.07', '1.09', '1.04', '1.01', '1.05', '1.12', '1.05', '1.04', '1.26', '1.05', '1.05', '1.07', '1.04', '1.14', '1.05', '1.05', '1.06', '0.98', '1.03', '1.24', '1.03', '1.04', '1.10', '1.01', '1.11', '1.11', '1.12', '1.06', '1.08', '1.04', '1.33', '1.04', '1.08', '1.07', '1.02', '1.04', '1.04', '1.04', '1.03', '1.03', '1.00', '1.21', '1.05', '1.03', '1.06', '1.02', '1.02', '1.07', '1.05', '1.12', '1.02', '1.12', '1.27', '1.01', '1.06', '1.04', '1.00', '1.10', '1.03', '1.08', '1.07', '1.08', '1.10', '1.52', '1.11', '1.06', '1.02', '1.08', '1.05', '1.04', '1.05', '1.05', '1.02', '1.06', '1.14', '1.04', '1.09', '1.09', '1.00', '1.06', '1.01', '1.06', '1.04', '1.01', '1.04', '1.32', '1.08', '1.07', '1.03', '1.02', '1.09', '1.10', '1.12', '1.06', '1.02', '1.01', '1.18', '1.04', '1.07', '1.15', '1.10', '1.10', '1.06', '1.07', '1.05', '1.10', '1.02', '1.60', '1.10', '1.02', '1.05', '1.07', '1.09', '1.01', '1.05', '1.08', '1.01', '1.05', '1.14', '1.02', '1.01', '1.02', '1.04', '1.07', '1.10', '1.03', '1.08', '1.04', '1.05', '1.22', '1.10', '1.03', '1.06', '1.08', '1.04', '1.02', '1.00', '1.02', '1.10', '1.02', '1.18', '1.06', '1.06', '1.03', '1.11', '1.07', '1.09', '1.02', '1.12', '1.01', '1.02', '1.23', '1.03', '1.03', '1.03', '1.11', '1.02', '1.02', '1.04', '1.04', '1.06', '1.02', '1.43', '1.04', '1.03', '1.05', '1.06', '1.11', '1.04', '1.02', '1.10', '1.02', '1.08', '1.12', '1.09', '1.02', '1.04', '1.05', '1.03', '1.10', '1.06', '1.04', '1.07', '1.06', '1.23', '1.04', '1.11', '1.05', '1.08', '1.02', '1.07', '1.05', '1.03', '1.05', '1.03', '1.60', '1.14', '1.08', '1.01', '1.04', '1.05', '1.04', '1.03', '1.08', '1.03', '1.06', '1.18', '1.00', '1.02', '1.07', '1.04', '1.07', '1.11', '1.04', '1.03', '1.06', '1.05', '1.15', '1.02', '1.01', '1.06', '1.07', '1.08', '1.03', '1.06', '1.10', '1.10', '1.06', '1.16', '1.03', '1.05', '0.98', '0.98', '0.97', '1.05', '1.04', '1.01', '1.05', '1.02', '1.25', '1.04', '0.98', '1.00', '0.97', '1.10', '1.03', '1.08', '1.02', '1.00', '1.03', '1.15', '0.99', '1.01', '1.00', '1.02', '1.06', '1.03', '1.03', '1.10', '1.05', '1.06', '1.14', '1.01', '1.08', '1.11', '1.03', '1.02', '1.01', '1.00']
x = [i for i in range (len(y))]

# %%
y = list(map(float, y))
x = list(map(float, x))

# %%
plt.figure(figsize = (10,5))
plt.plot(x,y)
# plt.xlim((max(x),min(x)))
# plt.ylim((min(y) - 0.1,max(y) + 0.1))
plt.xlim((min(x),max(x)))
plt.ylim((min(y),max(y)))
# plt.ylabel("推理时间")
# plt.xlabel("压缩率")
plt.ylabel("推理时间")
plt.xlabel("epoch")
plt.show()
